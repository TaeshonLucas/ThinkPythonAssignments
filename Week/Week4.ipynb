# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Week/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINETIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):

 # 2. Inside the function, use string multiplication (*) for a border line.
 border = "*" * 30
 __builtins__.print(border)

 # 3. Print the bio details using the parameter names.
 __builtins__.print(f"Name: {name}")
 __builtins__.print(f"Age: {age}")
 __builtins__.print(f"Goal: {goal}")
 __builtins__.print(border)

# PROGRAM LOGIC
# 1. Call print_bio using my own information.
print_bio("Taeshon", 18, "Become a Game Developer")

# 2. Call print_bio using [Famous Person].
print_bio("Vlad Savchuk", 37, "Spread the Gospel")

# 3. Call print_bio using [Fictional Character].
print_bio("Shaggy", 17, "Solving Mysteries")
# Out:
# ******************************
# Name: Taeshon
# Age: 18
# Goal: Become a Game Developer
# ******************************
# ******************************
# Name: Vlad Savchuk
# Age: 37
# Goal: Spread the Gospel
# ******************************
# ******************************
# Name: Shaggy
# Age: 17
# Goal: Solving Mysteries
# ******************************
