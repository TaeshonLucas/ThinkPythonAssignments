# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("The total minutes in a movie:", 2 * 60 + 45)
print("The years since 1947:", 2026 - 1947)
print("The total cost of 7 books:", 7 * 35)
# Out:
# The total minutes in a movie: 165
# The years since 1947: 79
# The total cost of 7 books: 245
