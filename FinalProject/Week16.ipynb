# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/FinalProject/Week16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PROGRAM OVERVIEW
# This program allows a user to enter espense records
# Each record contains a category, vendor, amount, and date
# All records are stored in a list of dictionaries
# The user can request totals for:
#   - all expenses
#   - expenses by category
#   - expenses by vendor
#  The program uses a menu-driven loop and runs until the user chooses to exit


# A single expense will be represented as a dictionary:
expenses =[]

def add_expense():
    print("\n--- Add New Expense ---")
    category = input("Enter category: ")
    vendor = input("Enter vendor: ")
    amount = float(input("Enter amount:"))
    date = input("Enter date (YYYY-MM-DD): ")
# expense = {
#     "category": string
#     "vendor": string
#     "amount": float
#     "date": string
# }
    expense = {
      "category": category,
      "vendor": vendor,
      "amount": amount,
      "date": date
}
# All expenses will be stored in a list:
# expenses = []
    expenses.append(expense)
print("Expense added!\n")

# MAIN TESTING LOOP
# -----------------
print(" Expense Tracker - Commit 2 Test\n")

while True:
    print("1. Add an expense")
    print("2. Show raw expense list")
    print("3. Exit test\n")

    choice = input("Enter your option: ")

    if choice == "1":
      add_expense()

    elif choice == "2":
      print("\nCurrent Expenses:")
      print(expenses)
      print()

    elif choice == "3":
      print("Exiting Commit 2 test...")
      break

    else:
      print("Invalid option\n")
# LOOP forever:
#     DISPLAY menu options:
#       1. Add new expense
#       2. Total of ALL expenses
#       3. Total by CATEGORY
#       4. Total by VENDOR
#       5. Exit program
#
#     Get user choice
#
#     IF choice == "1":
#       call add_expense()
#
#     ELSE IF choice =="2":
#       call total_all()
#       display the returned total
#
#     ELSE IF choice == "3":
#       ask user for category
#       call total_by_category(category)
#       display the returned total
#
#     ELSE IF choice == "4":
#       ask user for vendor
#       call total_by_vendor(vendor)
#       display the returned total
#
#     ELSE IF choice == "5":
#       display exit message
#       Break loop
#
#     ELSE:
#         display "Invalid choice"


# FUNCTION add_expense():
#     ASK user for category
#     ASK user for vendor
#     ASK user for amount (convert to float)
#     ASK user for date
#
#     CREATE dictionary with these values
#     APPEND dictionary to expenses list
#
#     DISPLAY confirmation message


# FUNCTION total_all():
#     SET running_total = 0
#
#     FOR each expense in expenses:
#         running_total += expense["amount"]
#
#     RETURN running_total


# FUNCTION total_by_category(category_name):
#     SET running_total = 0
#
#     FOR each expense in expenses:
#       IF expense["category"] == category_name:
#         running_total += expense["amount"]
#
#     RETURN running_total


# FUNCTION total_by_vendor(vendor_name):
#     SET running_total = 0
#
#     FOR each expense in expenses:
#       IF expense["vendor"] == vendor_name:
#         running_total += expense["amount"]
#
#     RETURN running_total


# When user selects option 5:
#       Display "Goodbye!"
#       END program
# Out:
# Expense added!
#
#  Expense Tracker - Commit 2 Test
#
# 1. Add an expense
# 2. Show raw expense list
# 3. Exit test
#
# Enter your option: 1
#
# --- Add New Expense ---
# Enter category: E
# Enter vendor: A
# Enter amount:59.99
# Enter date (YYYY-MM-DD): 1997-07-06
# 1. Add an expense
# 2. Show raw expense list
# 3. Exit test
#
# Enter your option: 2
#
# Current Expenses:
# [{'category': 'E', 'vendor': 'A', 'amount': 59.99, 'date': '1997-07-06'}]
#
# 1. Add an expense
# 2. Show raw expense list
# 3. Exit test
#
# Enter your option: 3
# Exiting Commit 2 test...
