# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Week5/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
def calculate_ticket(age, hour):
# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
    if age <= 12 or age >= 65:
      price = 8
    else:
      price = 12
# 3. Logic: If hour < 17, subtract 2 from the price.
    if hour < 17:
      price -= 2
# 4. Print the final price.
    print("Age_based price is", price)
# TEMPORARY TEST (Commit 2)
calculate_ticket(10, 19)
calculate_ticket(30, 19)
calculate_ticket(70, 19)
# PROGRAM LOGIC
# 1. input() for age (int)
# 2. input() for movie hour (int)
# 3. Call calculate_ticket()
# Out:
# Age_based price is 8
# Age_based price is 12
# Age_based price is 8
