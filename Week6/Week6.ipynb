# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Week6/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
import math

# FUNCTION DEFINITIONS
# 1. Define area(radius): returns pi * r squared
def area(radius):
    return math.pi * (radius**2)
# 2. Define circumference(radius): returns 2 * pi * r
def circumfrerence(radius):
    return 2 * math.pi * radius
# 3. Define volume(radius, height):
#    - Call area(radius) and multiply by height.
#    - Return the result.

# PROGRAM LOGIC
print("Testing with radius 5")
print("Area: ", area(5))
print("circumfrerence:", circumfrerence(5))
# 1. Input for radius (float)
# 2. Call and print area and circumference.
# 3. Input for height (float)
# 4. Call and print volume.
# Out:
# Testing with radius 5
# Area:  78.53981633974483
# circumfrerence: 31.41592653589793
