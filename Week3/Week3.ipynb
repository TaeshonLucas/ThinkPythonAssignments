# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assign values to variables: name, goal, birth_year, current_year
name = "Taeshon Lucas"
goal = "I want to understand coding"
birth_year = 2007
current_year = 2026
#Calculate Age
age = current_year - birth_year
#Print top border
print("=" * 25)
#Print bio sentence
print("My name is " + name + " and I am " + str(age) + " years old. ")
#Print bottom border
# Out:
# ...
# My name is Taeshon Lucas and I am 19 years old
