# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Week7/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
def verify_pin():
  pin = input("Enter your PIN:")
  while pin != "1234":
    print("Incorrect PIN")
    pin = input("Enter your PIN:")
    print("Correct PIN")
#    - Create a loop that asks for a PIN until it equals "1234"
#    - Return True if the PIN is correct
#    - Return False if the PIN is incorrect
# 2. Define withdraw(balance, amount):
#    - Check if enough money exists
#    - Return the new(or old) balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
# 2. Call verify_pin()
verify_pin()
# 3. Get withdrawal amount from user input
# 4. Update current_balance by calling withdraw()
# 5. Print the final balance
# Out:
# Enter your PIN:0000
# Incorrect PIN
# Enter your PIN:1234
# Correct PIN
