# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Week8/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENT
# (None)

# FUNCTION DEFINITION
# Define function is_palidrome that accepts one word
def is_palindrome(word):
# Convert word to lower case so capitalization doesn't matter
    word = word.lower()
# Reverse word using string slicing
    reversed_word = word[::-1]
# Compare the lowercase word to its reversed version
    return word == reversed_word
# Return True if they match, otherwise return False

# PROGRAM LOGIC
# Prompt the user to enter a word
# Call the is_palindrome function using the user's input
# Store the returned Boolean value
# If the function returned True, print a message saying the word Is a palindrome
# Otherwise, print a message saying the word is Not a palindrome
