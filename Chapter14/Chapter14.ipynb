# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeshonLucas/ThinkPythonAssignments/blob/main/Chapter14/Chapter14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS

# class Book:
class Book:
#     # __init__(self, title, author)
    def __init__(self, title, author):
#     # - store the title
        self.title = title
#     # - store the author
        self.author = author
#     # - set is_available to True by default
        self.is_available = True

#     # __str__(self)
    def __str__(self):
#     # - if is_available is True:
        if self.is_available:
#     #       return "<title> by <author> - Available"
            return f"{self.title} by {self.author} - Available"
#     #   else:
        else:
#     #      return "<title> by <author> - Checked Out"
            return f"{self.title} by {self.author} - Checked Out"

#     #   checkout(self)
    def checkout(self):
#     # - set is_available to False
        self.is_available = False

#     # return_book(self)
    def return_book(self):
#     # - set is_available to True
        self.is_available = True

# PROGRAM LOGIC

# Create two Book objects
book1 = Book("Think Python", "Allen Downey")
book2 = Book("The Hobbit", "J.R.R Tolkien")
# Print both books (this will call __str__)
print("--- Library Status ---")
print(book1)
print(book2)
# Call checkout() on one of them
print("\nChecking out 'Think Python'...\n")
book1.checkout()
# Print both books again to show the change
("--- Updated Status ---")
print(book1)
print(book2)
# Out:
# --- Library Status ---
# Think Python by Allen Downey - Available
# The Hobbit by J.R.R Tolkien - Available
#
# Checking out 'Think Python'...
#
# Think Python by Allen Downey - Checked Out
# The Hobbit by J.R.R Tolkien - Available
